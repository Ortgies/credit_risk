# %% [markdown]
# # Model tuning
# In the previous notebooks, I have assembled 290 features to predict if a client defaults on a given loan. <br>
# I will now try different models and methods to increase accuracy and hopefully achieve a ROC AUC of 0.8 on the test set.

# %% [markdown]
# ## TODO / Ideas
# - add batch noise to NN
# - Feed categorical embeddings from NN into LightGBM
# - Cross validation
# - Hyperparameter tuning
# - Ensembling

# %%
import pandas as pd
import numpy as np
from fastai.tabular.all import *
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import seaborn as sns
import gc

# %% [markdown]
# ## Set up datasets

# %%
df = pd.read_csv('dataset_reduced.csv', low_memory=False)
df.replace([np.inf, -np.inf], np.nan, inplace=True)

## make sure all category columns are classified as such
cat = list(df.select_dtypes(include=['category', 'object']).columns)
for c in cat:
    df[c] = df[c].astype('category')

train = df[df.test == 0].drop(columns=['test', 'SK_ID_CURR'])
test = df[df.test == 1].drop(columns=['test', 'SK_ID_CURR']) ## save away test set for later submission to kaggle

gc.enable()
del df
gc.collect()
# Out:
# 0

# %% [markdown]
# I want to compare LightGBM and Neural nets. To make sure both use the same train/test split, I manually assign the splits beforehand. This also allows me to do ensembling or to take outputs from the neural net and feed them into LightGBM without leaking information.

# %%
def valid_split(df, ratio, return_split=False):
    ix = np.random.choice(df.index, size=int(len(df)*ratio), replace=False)
    df['valid'] = False
    df.loc[ix, 'valid'] = True

    return df

# %%
def split_datasets(df):
    X_train = df[df.valid == False].drop(columns=['valid', 'TARGET'])
    X_test = df[df.valid == True].drop(columns=['valid', 'TARGET'])
    y_train = df.loc[df.valid == False, 'TARGET']
    y_test = df.loc[df.valid == True, 'TARGET']
    
    return X_train, X_test, y_train, y_test

# %%
train = valid_split(train, 0.2)

# %%
train.head()
# Out:
#    TARGET NAME_CONTRACT_TYPE CODE_GENDER  AMT_CREDIT  AMT_ANNUITY  \
# 0     1.0         Cash loans           M    406597.5      24700.5
# 1     0.0         Cash loans           F   1293502.5      35698.5
# 2     0.0    Revolving loans           M    135000.0       6750.0
# 3     0.0         Cash loans           F    312682.5      29686.5
# 4     0.0         Cash loans           M    513000.0      21865.5
#
#              NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  \
# 0  Secondary / secondary special  Single / not married
# 1               Higher education               Married
# 2  Secondary / secondary special  Single / not married
# 3  Secondary / secondary special        Civil marriage
# 4  Secondary / secondary special  Single / not married
#
#    REGION_POPULATION_RELATIVE  DAYS_BIRTH  DAYS_EMPLOYED  ...  \
# 0                    0.018801       -9461         -637.0  ...
# 1                    0.003541      -16765        -1188.0  ...
# 2                    0.010032      -19046         -225.0  ...
# 3                    0.008019      -19005        -3039.0  ...
# 4                    0.028663      -19932        -3038.0  ...
#
#    client_installments_AMT_PAYMENT_sum_min  \
# 0                               219625.700
# 1                                80773.380
# 2                                21288.465
# 3                                25091.324
# 4                                18330.390
#
#    client_installments_AMT_INSTALMENT_max_max  \
# 0                                   53093.746
# 1                                  560835.400
# 2                                   10573.965
# 3                                  691786.900
# 4                                   22678.785
#
#    client_installments_AMT_PAYMENT_sum_mean  \
# 0                                219625.700
# 1                                453952.220
# 2                                 21288.465
# 3                                232499.700
# 4                                172669.890
#
#    client_installments_AMT_PAYMENT_min_sum  \
# 0                                175783.73
# 1                               1154108.20
# 2                                 16071.75
# 3                                994476.70
# 4                                483756.38
#
#   client_installments_AMT_INSTALMENT_min_sum  \
# 0                                  175783.73
# 1                                 1154108.20
# 2                                   16071.75
# 3                                  994476.70
# 4                                  825845.80
#
#    client_installments_AMT_PAYMENT_sum_max  \
# 0                               219625.700
# 1                              1150977.400
# 2                                21288.465
# 3                               691786.900
# 4                               280199.700
#
#   client_installments_AMT_PAYMENT_mean_sum  \
# 0                               219625.690
# 1                              1618864.600
# 2                                21288.465
# 3                              1007153.400
# 4                               806127.940
#
#    client_installments_AMT_INSTALMENT_max_sum  \
# 0                                 1008781.200
# 1                                 4394101.500
# 2                                   31721.895
# 3                                 1057860.200
# 4                                  836703.400
#
#    client_installments_AMT_PAYMENT_sum_sum  valid
# 0                             4.172888e+06  False
# 1                             1.134881e+07  False
# 2                             6.386539e+04  False
# 3                             3.719995e+06  False
# 4                             1.139621e+07  False
#
# [5 rows x 292 columns]

# %% [markdown]
# ## Get baseline - LightGBM
# LightGBM achieves a ROC AUC of 0.7850, which is very good already. <br>
# There are 14528 false negatives and 1562 false positives.

# %%
X_train, X_test, y_train, y_test = split_datasets(train)

# %%
model = lgb.LGBMClassifier(objective='binary', boosting_type = 'goss', n_estimators = 10000, class_weight = 'balanced')

# %%
model.fit(X_train, y_train, eval_set = [(X_test, y_test)], eval_metric = 'auc',
          callbacks = [lgb.early_stopping(100), lgb.log_evaluation(100)])
# Out:
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1513: UserWarning: categorical_column in param dict is overridden.
#   _log_warning(f'{cat_alias} in param dict is overridden.')
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.783556	valid_0's binary_logloss: 0.536169
# [200]	valid_0's auc: 0.784324	valid_0's binary_logloss: 0.50847
# Early stopping, best iteration is:
# [142]	valid_0's auc: 0.785026	valid_0's binary_logloss: 0.522866
# LGBMClassifier(boosting_type='goss', class_weight='balanced',
#                n_estimators=10000, objective='binary')

# %%
def print_confusion(model):
    pred = model.predict(X_test)
    cm = confusion_matrix(y_test, pred)
    
    cm_matrix = pd.DataFrame(data=cm, columns=['Actual No Default', 'Actual Default'], 
                                 index=['Predict No Default', 'Predict Default'])
    
    sns.heatmap(cm_matrix, annot=True, fmt='d', cmap='YlGnBu')

# %%
print_confusion(model)

# %% [markdown]
# ### Oversampling
# Only around 8% of all loans in the dataset default. Class imbalance could potentially be a problem. <br>
# I randomly oversample default loans up to 50% of the non-default loans. In other words, the resulting dataset contains 1/3 default loans.

# %%
def oversample(X, y, ratio=0.5, noise=False):
    df = X.copy()
    df['TARGET'] = y

    n_maj = len(df[df.TARGET == 0])
    n_min = len(df[df.TARGET == 1])
    current_ratio = n_min / n_maj
    
    n_new = int(ratio / current_ratio * n_min - n_min)
    print('Build {} new features.'.format(n_new))
    
    new_sample = df[df.TARGET == 1].sample(n_new, replace=True, ignore_index=True)
    
    df = df.append(new_sample)
    
    return df.drop(columns=['TARGET']), df['TARGET']

# %%
X_train_os, y_train_os = oversample(X_train, y_train)
# Out:
# Build 93245 new features.

# %%
len(X_train_os),len(y_train_os)
# Out:
# (339254, 339254)

# %% [markdown]
# The model performs slightly worse. Random Forests are pretty robust to class imbalance, so oversampling is probably not necessary. <br>
# Maybe more advanced oversampling methods like SMOTE could net better results.

# %%
model = lgb.LGBMClassifier(objective='binary', boosting_type = 'goss', n_estimators = 10000, class_weight = 'balanced')

# %%
model.fit(X_train_os, y_train_os, eval_set = [(X_test, y_test)], eval_metric = 'auc',
          callbacks = [lgb.early_stopping(100), lgb.log_evaluation(100)])
# Out:
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1780: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1513: UserWarning: categorical_column in param dict is overridden.
#   _log_warning(f'{cat_alias} in param dict is overridden.')
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.779394	valid_0's binary_logloss: 0.532078
# [200]	valid_0's auc: 0.779918	valid_0's binary_logloss: 0.501908
# Early stopping, best iteration is:
# [158]	valid_0's auc: 0.780573	valid_0's binary_logloss: 0.513208
# LGBMClassifier(boosting_type='goss', class_weight='balanced',
#                n_estimators=10000, objective='binary')

# %%
print_confusion(model)

# %%
gc.enable()
del X_train_os, y_train_os
gc.collect()
# Out:
# 9775

# %% [markdown]
# ## Neural net
# I try out a neural net for comparison. <br>
# While the ROC AUC isnt that much worse at 0.7737, the confusion matrix shows that the algorithm is almost incapable of predicting defaults. Only 207 defaults are correctly classified.

# %%
valid_idx = list(train[train.valid == True].index)
cont_names, cat_names = cont_cat_split(train, dep_var='TARGET')

procs = [Categorify, FillMissing, Normalize]
dls = TabularDataLoaders.from_df(train, valid_idx=valid_idx, procs=procs, cat_names=cat_names, cont_names=cont_names, y_names='TARGET', y_block=CategoryBlock, bs=512)
dls.show_batch()
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1667: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = value
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>NAME_CONTRACT_TYPE</th>
#       <th>CODE_GENDER</th>
#       <th>NAME_EDUCATION_TYPE</th>
#       <th>NAME_FAMILY_STATUS</th>
#       <th>FLAG_WORK_PHONE</th>
#       <th>OCCUPATION_TYPE</th>
#       <th>REGION_RATING_CLIENT</th>
#       <th>WEEKDAY_APPR_PROCESS_START</th>
#       <th>REG_CITY_NOT_LIVE_CITY</th>
#       <th>ORGANIZATION_TYPE</th>
#       <th>WALLSMATERIAL_MODE</th>
#       <th>FLAG_DOCUMENT_3</th>
#       <th>FLAG_DOCUMENT_16</th>
#       <th>valid</th>
#       <th>AMT_ANNUITY_na</th>
#       <th>DAYS_EMPLOYED_na</th>
#       <th>OWN_CAR_AGE_na</th>
#       <th>EXT_SOURCE_1_na</th>
#       <th>EXT_SOURCE_2_na</th>
#       <th>EXT_SOURCE_3_na</th>
#       <th>APARTMENTS_AVG_na</th>
#       <th>BASEMENTAREA_AVG_na</th>
#       <th>YEARS_BEGINEXPLUATATION_AVG_na</th>
#       <th>YEARS_BUILD_AVG_na</th>
#       <th>COMMONAREA_AVG_na</th>
#       <th>ENTRANCES_AVG_na</th>
#       <th>FLOORSMAX_AVG_na</th>
#       <th>FLOORSMIN_AVG_na</th>
#       <th>LANDAREA_AVG_na</th>
#       <th>LIVINGAREA_AVG_na</th>
#       <th>NONLIVINGAPARTMENTS_AVG_na</th>
#       <th>NONLIVINGAREA_AVG_na</th>
#       <th>OBS_30_CNT_SOCIAL_CIRCLE_na</th>
#       <th>DEF_30_CNT_SOCIAL_CIRCLE_na</th>
#       <th>DEF_60_CNT_SOCIAL_CIRCLE_na</th>
#       <th>DAYS_LAST_PHONE_CHANGE_na</th>
#       <th>AMT_REQ_CREDIT_BUREAU_QRT_na</th>
#       <th>annuity_pct_na</th>
#       <th>credit_term_na</th>
#       <th>ext_mean_na</th>
#       <th>bureau_CREDIT_TYPE_Mortgage_mean_x_na</th>
#       <th>bureau_CREDIT_TYPE_Microloan_mean_x_na</th>
#       <th>bureau_CREDIT_TYPE_Carloan_mean_x_na</th>
#       <th>bureau_CREDIT_TYPE_Creditcard_sum_x_na</th>
#       <th>bureau_CREDIT_ACTIVE_Active_mean_x_na</th>
#       <th>bureau_CREDIT_TYPE_Consumercredit_mean_x_na</th>
#       <th>bureau_CREDIT_ACTIVE_Active_sum_x_na</th>
#       <th>bureau_CREDIT_ACTIVE_Closed_sum_x_na</th>
#       <th>bureau_DAYS_CREDIT_sum_x_na</th>
#       <th>bureau_DAYS_CREDIT_min_x_na</th>
#       <th>bureau_DAYS_CREDIT_ENDDATE_min_x_na</th>
#       <th>bureau_DAYS_ENDDATE_FACT_min_x_na</th>
#       <th>bureau_DAYS_ENDDATE_FACT_mean_x_na</th>
#       <th>bureau_DAYS_CREDIT_mean_x_na</th>
#       <th>bureau_DAYS_ENDDATE_FACT_max_x_na</th>
#       <th>bureau_DAYS_CREDIT_UPDATE_min_x_na</th>
#       <th>bureau_DAYS_CREDIT_UPDATE_mean_x_na</th>
#       <th>bureau_DAYS_CREDIT_max_x_na</th>
#       <th>bureau_DAYS_CREDIT_UPDATE_max_x_na</th>
#       <th>bureau_AMT_CREDIT_SUM_OVERDUE_mean_x_na</th>
#       <th>bureau_AMT_CREDIT_SUM_OVERDUE_max_x_na</th>
#       <th>bureau_AMT_CREDIT_SUM_DEBT_min_x_na</th>
#       <th>bureau_AMT_CREDIT_MAX_OVERDUE_count_x_na</th>
#       <th>bureau_AMT_CREDIT_SUM_LIMIT_mean_x_na</th>
#       <th>bureau_AMT_CREDIT_MAX_OVERDUE_sum_x_na</th>
#       <th>bureau_AMT_CREDIT_SUM_LIMIT_sum_x_na</th>
#       <th>bureau_credit_term_mean_x_na</th>
#       <th>bureau_AMT_CREDIT_SUM_LIMIT_count_x_na</th>
#       <th>bureau_credit_term_count_x_na</th>
#       <th>bureau_DAYS_CREDIT_ENDDATE_mean_x_na</th>
#       <th>bureau_DAYS_CREDIT_ENDDATE_sum_x_na</th>
#       <th>bureau_DAYS_CREDIT_ENDDATE_max_x_na</th>
#       <th>bureau_AMT_ANNUITY_max_x_na</th>
#       <th>bureau_AMT_CREDIT_SUM_DEBT_mean_x_na</th>
#       <th>bureau_AMT_CREDIT_SUM_min_x_na</th>
#       <th>bureau_AMT_CREDIT_SUM_mean_x_na</th>
#       <th>bureau_AMT_CREDIT_SUM_DEBT_max_x_na</th>
#       <th>client_bureau_balance_MONTHS_BALANCE_sum_min_na</th>
#       <th>client_bureau_balance_MONTHS_BALANCE_max_sum_na</th>
#       <th>client_bureau_balance_MONTHS_BALANCE_max_mean_na</th>
#       <th>client_bureau_balance_STATUS_1_mean_mean_na</th>
#       <th>client_bureau_balance_STATUS_0_mean_min_na</th>
#       <th>client_bureau_balance_STATUS_X_mean_mean_na</th>
#       <th>client_bureau_balance_STATUS_0_mean_mean_na</th>
#       <th>client_bureau_balance_STATUS_C_mean_mean_na</th>
#       <th>client_bureau_balance_STATUS_X_mean_max_na</th>
#       <th>client_bureau_balance_STATUS_C_mean_max_na</th>
#       <th>client_bureau_balance_STATUS_0_mean_max_na</th>
#       <th>client_bureau_balance_STATUS_1_sum_max_na</th>
#       <th>client_bureau_balance_STATUS_X_mean_sum_na</th>
#       <th>client_bureau_balance_STATUS_0_mean_sum_na</th>
#       <th>client_bureau_balance_STATUS_C_mean_sum_na</th>
#       <th>client_bureau_balance_STATUS_X_sum_mean_na</th>
#       <th>client_bureau_balance_STATUS_0_sum_mean_na</th>
#       <th>client_bureau_balance_STATUS_0_sum_max_na</th>
#       <th>client_bureau_balance_STATUS_0_sum_sum_na</th>
#       <th>previous_DAYS_DECISION_sum_na</th>
#       <th>previous_DAYS_DECISION_min_na</th>
#       <th>previous_DAYS_DECISION_mean_na</th>
#       <th>previous_DAYS_DECISION_max_na</th>
#       <th>previous_DAYS_FIRST_DUE_min_na</th>
#       <th>previous_DAYS_FIRST_DUE_mean_na</th>
#       <th>previous_DAYS_LAST_DUE_sum_na</th>
#       <th>previous_DAYS_LAST_DUE_min_na</th>
#       <th>previous_DAYS_LAST_DUE_mean_na</th>
#       <th>previous_DAYS_LAST_DUE_max_na</th>
#       <th>previous_DAYS_LAST_DUE_1ST_VERSION_sum_na</th>
#       <th>previous_DAYS_LAST_DUE_1ST_VERSION_min_na</th>
#       <th>previous_DAYS_LAST_DUE_1ST_VERSION_mean_na</th>
#       <th>previous_credit_delta_min_na</th>
#       <th>previous_credit_delta_mean_na</th>
#       <th>previous_credit_delta_max_na</th>
#       <th>previous_credit_delta_sum_na</th>
#       <th>previous_NFLAG_INSURED_ON_APPROVAL_mean_na</th>
#       <th>previous_NFLAG_INSURED_ON_APPROVAL_sum_na</th>
#       <th>previous_RATE_DOWN_PAYMENT_min_na</th>
#       <th>previous_RATE_DOWN_PAYMENT_mean_na</th>
#       <th>previous_RATE_DOWN_PAYMENT_max_na</th>
#       <th>previous_RATE_DOWN_PAYMENT_sum_na</th>
#       <th>previous_credit_term_min_na</th>
#       <th>previous_credit_term_mean_na</th>
#       <th>previous_credit_term_max_na</th>
#       <th>previous_credit_term_sum_na</th>
#       <th>previous_CNT_PAYMENT_mean_na</th>
#       <th>previous_CNT_PAYMENT_max_na</th>
#       <th>previous_CNT_PAYMENT_sum_na</th>
#       <th>previous_HOUR_APPR_PROCESS_START_min_na</th>
#       <th>previous_HOUR_APPR_PROCESS_START_mean_na</th>
#       <th>previous_HOUR_APPR_PROCESS_START_max_na</th>
#       <th>previous_SELLERPLACE_AREA_min_na</th>
#       <th>previous_SELLERPLACE_AREA_mean_na</th>
#       <th>previous_SELLERPLACE_AREA_max_na</th>
#       <th>previous_SELLERPLACE_AREA_sum_na</th>
#       <th>previous_AMT_DOWN_PAYMENT_mean_na</th>
#       <th>previous_AMT_DOWN_PAYMENT_max_na</th>
#       <th>previous_AMT_ANNUITY_min_na</th>
#       <th>previous_AMT_ANNUITY_mean_na</th>
#       <th>previous_AMT_ANNUITY_max_na</th>
#       <th>previous_AMT_ANNUITY_sum_na</th>
#       <th>previous_AMT_CREDIT_min_na</th>
#       <th>previous_AMT_CREDIT_mean_na</th>
#       <th>previous_AMT_CREDIT_max_na</th>
#       <th>previous_AMT_GOODS_PRICE_min_na</th>
#       <th>previous_CODE_REJECT_REASON_SCOFR_mean_na</th>
#       <th>previous_CHANNEL_TYPE_Channelofcorporatesales_mean_na</th>
#       <th>previous_CODE_REJECT_REASON_SCO_mean_na</th>
#       <th>previous_CODE_REJECT_REASON_HC_mean_na</th>
#       <th>previous_NAME_SELLER_INDUSTRY_Clothing_mean_na</th>
#       <th>previous_PRODUCT_COMBINATION_CashStreetlow_mean_na</th>
#       <th>previous_CHANNEL_TYPE_Contactcenter_mean_na</th>
#       <th>previous_PRODUCT_COMBINATION_POSindustrywithoutinterest_mean_na</th>
#       <th>previous_NAME_YIELD_GROUP_low_action_mean_na</th>
#       <th>previous_WEEKDAY_APPR_PROCESS_START_WEDNESDAY_mean_na</th>
#       <th>previous_PRODUCT_COMBINATION_CashStreethigh_mean_na</th>
#       <th>previous_CHANNEL_TYPE_APCashloan_mean_na</th>
#       <th>previous_NAME_PRODUCT_TYPE_walkin_mean_na</th>
#       <th>previous_WEEKDAY_APPR_PROCESS_START_MONDAY_mean_na</th>
#       <th>previous_NAME_PRODUCT_TYPE_walkin_sum_na</th>
#       <th>previous_NAME_SELLER_INDUSTRY_Construction_mean_na</th>
#       <th>previous_PRODUCT_COMBINATION_CashXSellhigh_mean_na</th>
#       <th>previous_CODE_REJECT_REASON_LIMIT_mean_na</th>
#       <th>previous_NAME_CONTRACT_STATUS_Refused_mean_na</th>
#       <th>previous_PRODUCT_COMBINATION_CardXSell_mean_na</th>
#       <th>previous_WEEKDAY_APPR_PROCESS_START_TUESDAY_mean_na</th>
#       <th>previous_NAM

# %%
learn = tabular_learner(dls, metrics=[RocAucBinary()], cbs=[EarlyStoppingCallback(patience=3), SaveModelCallback()])

# %%
learn.lr_find()
# Out:
# SuggestedLRs(valley=0.0012022644514217973)

# %%
learn.fit(10, 0.001)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>roc_auc_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.248392</td>
#       <td>0.248837</td>
#       <td>0.764030</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.243027</td>
#       <td>0.246021</td>
#       <td>0.767464</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.241204</td>
#       <td>0.244987</td>
#       <td>0.771192</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.240369</td>
#       <td>0.244533</td>
#       <td>0.773709</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.235080</td>
#       <td>0.248937</td>
#       <td>0.771360</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.228056</td>
#       <td>0.249938</td>
#       <td>0.769186</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.228972</td>
#       <td>0.251602</td>
#       <td>0.763807</td>
#       <td>00:17</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.24883659183979034.
# Better model found at epoch 1 with valid_loss value: 0.2460208684206009.
# Better model found at epoch 2 with valid_loss value: 0.24498698115348816.
# Better model found at epoch 3 with valid_loss value: 0.24453258514404297.
# No improvement since epoch 3: early stopping

# %%
def print_confusion_nn(learner):
    pred, targ = learn.get_preds(dl=dls.valid)
    pred = np.arange(pred.shape[1])[np.argmax(pred, axis=1)]
    
    cm = confusion_matrix(targ, pred)
    
    cm_matrix = pd.DataFrame(data=cm, columns=['Actual No Default', 'Actual Default'], 
                            index=['Predict No Default', 'Predict Default'])
    
    sns.heatmap(cm_matrix, annot=True, fmt='d', cmap='YlGnBu')

# %%
print_confusion_nn(learn)

# %%
gc.enable()
del learn, dls, valid_idx, cont_names, cat_names, procs
gc.collect()
# Out:
# 17502

# %% [markdown]
# ## Hyperparameter tuning
# Since Gradient Boosting is clearly the superior approach for this type of problem, I need to tune the LightGBM hyperparameters next. <br>
# I plan on doing a random search for a number of periods and then continue with a more focused grid search. <br>
# A single 5-fold cross validation takes around 30 seconds, so I will probably do this step over Kaggle or Google Colab.

# %%
train = train.drop(columns=['valid'])

# %%
features = train.sample(n=15000, random_state=13)
labels = train['TARGET']
features = train.drop(columns = ['TARGET'])

train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size = 60000, random_state = 13)
train_features.shape,test_features.shape
# Out:
# ((247511, 290), (60000, 290))

# %%
train_set = lgb.Dataset(data = train_features, label = train_labels)
test_set = lgb.Dataset(data = test_features, label = test_labels)

# %%
model = lgb.LGBMClassifier()

default_params = model.get_params()
del default_params['n_estimators']

# %%
def get_score(hyperparameters, iteration):

    if 'n_estimators' in hyperparameters.keys():
        del hyperparameters['n_estimators']
    
    results = lgb.cv(hyperparameters, train_set, num_boost_round = 10000, nfold = 5, 
                     metrics = 'auc', seed = 13, callbacks = [lgb.early_stopping(50)])
    
    score = results['auc-mean'][-1]
    estimators = len(results['auc-mean'])
    hyperparameters['n_estimators'] = estimators 
    
    return [score, hyperparameters, iteration]

# %% [markdown]
# The default parameters result in a ROC AUC of 0.7754. This is the baseline going forward.

# %%
# %%time
# %%capture

score, params, iteration = get_score(default_params, 1)
# Out:
# CPU times: user 3min 3s, sys: 666 ms, total: 3min 4s
# Wall time: 30.9 s

# %%
print(score)
# Out:
# 0.7754111424187158

# %%
param_grid = {
    'boosting_type': ['gbdt', 'goss'],
    'num_leaves': list(range(20, 150)),
    'learning_rate': list(np.logspace(np.log10(0.005), np.log10(0.5), base = 10, num = 1000)),
    'min_child_samples': list(range(20, 500, 5)),
    'reg_alpha': list(np.linspace(0, 1)),
    'reg_lambda': list(np.linspace(0, 1)),
    'colsample_bytree': list(np.linspace(0.6, 1, 10)),
    'subsample': list(np.linspace(0.5, 1, 100)),
    'is_unbalance': [True, False]
}

# %%
def random_search(param_grid, iterations = 2):

    results = pd.DataFrame(columns = ['score', 'params', 'iteration'], index = list(range(iterations)))
    
    for i in range(iterations):
        
        hyperparameters = {k: random.sample(v, 1)[0] for k, v in param_grid.items()}
        hyperparameters['subsample'] = 1.0 if hyperparameters['boosting_type'] == 'goss' else hyperparameters['subsample']

        score = get_score(hyperparameters, i)
        results.loc[i, :] = score

    results.sort_values('score', ascending = False, inplace = True)
    results.reset_index(inplace = True)
    return results

# %%
# %%time
# %%capture

random_results = random_search(param_grid)

# %%
print('The best validation score was {:.4f}'.format(random_results.loc[0, 'score']))
print('\nThe best hyperparameters were: {}'.format(random_results.loc[0, 'params']))
